# %%
import pandas as pd

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_excel("/Users/shivamyadav/Downloads/IRIS_Accuracy_PROJECT/iris-train.xlsx")

# %%
data.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth           class
# 0          7.9         3.8          6.4         2.0  Iris-virginica
# 1          7.7         3.8          6.7         2.2  Iris-virginica
# 2          7.7         3.0          6.1         2.3  Iris-virginica
# 3          7.7         2.8          6.7         2.0  Iris-virginica
# 4          7.7         2.6          6.9         2.3  Iris-virginica

# %%
x = data.iloc[:, :-1]

# %%
x
# Out:
#      sepallength  sepalwidth  petallength  petalwidth
# 0            7.9         3.8          6.4         2.0
# 1            7.7         3.8          6.7         2.2
# 2            7.7         3.0          6.1         2.3
# 3            7.7         2.8          6.7         2.0
# 4            7.7         2.6          6.9         2.3
# ..           ...         ...          ...         ...
# 111          4.5         2.3          1.3         0.3
# 112          4.4         3.2          1.3         0.2
# 113          4.4         3.0          1.3         0.2
# 114          4.4         2.9          1.4         0.2
# 115          4.3         3.0          1.1         0.1
#
# [116 rows x 4 columns]

# %%
y = data.iloc[:, -1]

# %%
y
# Out:
# 0      Iris-virginica
# 1      Iris-virginica
# 2      Iris-virginica
# 3      Iris-virginica
# 4      Iris-virginica
#             ...
# 111       Iris-setosa
# 112       Iris-setosa
# 113       Iris-setosa
# 114       Iris-setosa
# 115       Iris-setosa
# Name: class, Length: 116, dtype: object

# %%
model = RandomForestClassifier()

# %%
x.values
# Out:
# array([[7.9, 3.8, 6.4, 2. ],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 3. , 6.1, 2.3],
#        [7.7, 2.8, 6.7, 2. ],
#        [7.7, 2.6, 6.9, 2.3],
#        [7.6, 3. , 6.6, 2.1],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.3, 2.9, 6.3, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [7.2, 3.2, 6. , 1.8],
#        [7.2, 3. , 5.8, 1.6],
#        [7.1, 3. , 5.9, 2.1],
#        [7. , 3.2, 4.7, 1.4],
#        [6.9, 3.2, 5.7, 2.3],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.9, 3.1, 5.1, 2.3],
#        [6.9, 3.1, 4.9, 1.5],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.8, 3. , 5.5, 2.1],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3.3, 5.7, 2.1],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.7, 3.1, 4.4, 1.4],
#        [6.7, 3. , 5.2, 2.3],
#        [6.7, 3. , 5. , 1.7],
#        [6.7, 2.5, 5.8, 1.8],
#        [6.6, 3. , 4.4, 1.4],
#        [6.6, 2.9, 4.6, 1.3],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.5, 3. , 5.8, 2.2],
# ...

# %%
model.fit(x.values, y.values)
# Out:
# RandomForestClassifier()

# %%
predictions = model.predict([[5.3,	3.7,	1.5,	0.2]])

# %%
predictions
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
datatest = pd.read_excel("/Users/shivamyadav/Downloads/IRIS_Accuracy_PROJECT/iris-test.xlsx")     #Now, for testing purpose

# %%
x_test = datatest.iloc[:, :-1]

# %%
predictions = model.predict(x_test.values)

# %%
predictions
# Out:
# array(['Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa'], dtype=object)

# %%
y_test = datatest.iloc[:, -1]

# %%
actual = y_test.values

# %%
actual
# Out:
# array(['Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa'], dtype=object)

# %%
count = 0
for i in range(0, len(actual)):
    if actual[i] == predictions[i]:
        count = count + 1
        print((count * 100)/len(actual))
# Out:
# 2.9411764705882355
# 5.882352941176471
# 8.823529411764707
# 11.764705882352942
# 14.705882352941176
# 17.647058823529413
# 20.58823529411765
# 23.529411764705884
# 26.470588235294116
# 29.41176470588235
# 32.35294117647059
# 35.294117647058826
# 38.23529411764706
# 41.1764705882353
# 44.11764705882353
# 47.05882352941177
# 50.0
# 52.94117647058823
# 55.88235294117647
# 58.8235294117647
# 61.76470588235294
# 64.70588235294117
# 67.6470588235294
# 70.58823529411765
# 73.52941176470588
# 76.47058823529412
# 79.41176470588235
# 82.3529411764706
# 85.29411764705883
# 88.23529411764706
# 91.17647058823529
# 94.11764705882354
# 97.05882352941177

# %%
y_test = datatest.iloc[:, -1]
