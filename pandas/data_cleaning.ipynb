# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/shivamyadav/Downloads/sample_users.csv")

# %%
df
# Out:
#                    Name   Age  Gender               City  \
# 0         Kristen Weeks  33.0  Female       West Theresa
# 1          Ryan Jackson  30.0    Male        Tiffanybury
# 2       Tara Montgomery   NaN     NaN          Perezstad
# 3     Ashley Salazar MD  28.0  Female       South Janice
# 4            Jeff Scott  31.0    Male       Port Jasmine
# 5         Timothy Allen  47.0  Female        Caitlinview
# 6       Stephen Edwards  39.0  Female  Port Michaelhaven
# 7         Brandon Perry  33.0  Female                NaN
# 8           Robert Bell  21.0    Male     East Heidifort
# 9   Mr. Timothy Morales  24.0  Female       Wattsborough
# 10        Kristen Weeks  33.0  Female       West Theresa
# 11         Ryan Jackson  30.0    Male        Tiffanybury
# 12      Tara Montgomery   NaN     NaN          Perezstad
# 13    Ashley Salazar MD  28.0  Female       South Janice
#
#                        Email   Join Date
# 0   vegajose@weaver-rice.com   6/19/2022
# ...

# %%
df.isnull()
# Out:
#     Name    Age  Gender   City  Email  Join Date
# 0  False  False   False  False  False      False
# 1  False  False   False  False  False      False
# 2  False   True    True  False  False      False
# 3  False  False   False  False  False      False
# 4  False  False   False  False  False      False
# 5  False  False   False  False   True      False
# 6  False  False   False  False  False      False
# 7  False  False   False   True  False      False
# 8  False  False   False  False  False      False
# 9  False  False   False  False  False       True

# %%
df.isnull().sum()
# Out:
# Name         0
# Age          1
# Gender       1
# City         1
# Email        1
# Join Date    1
# dtype: int64

# %%
df.dropna()
# Out:
#                 Name   Age  Gender               City  \
# 0      Kristen Weeks  33.0  Female       West Theresa
# 1       Ryan Jackson  30.0    Male        Tiffanybury
# 3  Ashley Salazar MD  28.0  Female       South Janice
# 4         Jeff Scott  31.0    Male       Port Jasmine
# 6    Stephen Edwards  39.0  Female  Port Michaelhaven
# 8        Robert Bell  21.0    Male     East Heidifort
#
#                       Email   Join Date
# 0  vegajose@weaver-rice.com   6/19/2022
# 1   johnsonthomas@gmail.com   11/2/2024
# 3       herbertgray@gay.com  12/11/2022
# 4  cassandrapena@robles.org  10/27/2024
# 6        sherry55@gmail.com    9/5/2022
# 8           ssnow@yahoo.com   6/14/2025

# %%
df.dropna(axis = 1)
# Out:
#                   Name
# 0        Kristen Weeks
# 1         Ryan Jackson
# 2      Tara Montgomery
# 3    Ashley Salazar MD
# 4           Jeff Scott
# 5        Timothy Allen
# 6      Stephen Edwards
# 7        Brandon Perry
# 8          Robert Bell
# 9  Mr. Timothy Morales

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#                   Name   Age  Gender               City  \
# 0        Kristen Weeks  33.0  Female       West Theresa
# 1         Ryan Jackson  30.0    Male        Tiffanybury
# 2      Tara Montgomery   NaN     NaN          Perezstad
# 3    Ashley Salazar MD  28.0  Female       South Janice
# 4           Jeff Scott  31.0    Male       Port Jasmine
# 5        Timothy Allen  47.0  Female        Caitlinview
# 6      Stephen Edwards  39.0  Female  Port Michaelhaven
# 7        Brandon Perry  33.0  Female                NaN
# 8          Robert Bell  21.0    Male     East Heidifort
# 9  Mr. Timothy Morales  24.0  Female       Wattsborough
#
#                       Email   Join Date
# 0  vegajose@weaver-rice.com   6/19/2022
# 1   johnsonthomas@gmail.com   11/2/2024
# 2   ashleyedwards@gmail.com   5/26/2021
# 3       herbertgray@gay.com  12/11/2022
# 4  cassandrapena@robles.org  10/27/2024
# 5                       NaN    7/5/2022
# 6        sherry55@gmail.com    9/5/2022
# ...

# %%
df["Name"].str.lower()
# Out:
# 0           kristen weeks
# 1            ryan jackson
# 2         tara montgomery
# 3       ashley salazar md
# 4              jeff scott
# 5           timothy allen
# 6         stephen edwards
# 7           brandon perry
# 8             robert bell
# 9     mr. timothy morales
# 10          kristen weeks
# 11           ryan jackson
# 12        tara montgomery
# 13      ashley salazar md
# Name: Name, dtype: object

# %%
df["City"].str.contains("Wattsborough", case = False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7       NaN
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# Name: City, dtype: object

# %%
type(df["City"].str.contains("Wattsborough", case = False))
# Out:
# pandas.core.series.Series

# %%
df["Age Group"] = df["Age"].apply(lambda x : "Adult" if x >= 30 else "Minor")

# %%
df
# Out:
#                    Name   Age  Gender               City  \
# 0         Kristen Weeks  33.0  Female       West Theresa
# 1          Ryan Jackson  30.0    Male        Tiffanybury
# 2       Tara Montgomery   NaN     NaN          Perezstad
# 3     Ashley Salazar MD  28.0  Female       South Janice
# 4            Jeff Scott  31.0    Male       Port Jasmine
# 5         Timothy Allen  47.0  Female        Caitlinview
# 6       Stephen Edwards  39.0  Female  Port Michaelhaven
# 7         Brandon Perry  33.0  Female                NaN
# 8           Robert Bell  21.0    Male     East Heidifort
# 9   Mr. Timothy Morales  24.0  Female       Wattsborough
# 10        Kristen Weeks  33.0  Female       West Theresa
# 11         Ryan Jackson  30.0    Male        Tiffanybury
# 12      Tara Montgomery   NaN     NaN          Perezstad
# 13    Ashley Salazar MD  28.0  Female       South Janice
#
#                        Email   Join Date Age Group
# 0   vegajose@weaver-rice.com   6/19/2022     Adult
# ...
