# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/shivamyadav/Downloads/actors.csv")

# %%
df
# Out:
#             Actor  Total Box Office (INR Cr)  Average IMDb Rating  \
# 0  Shah Rukh Khan                       2200                  7.8
# 1     Salman Khan                       2500                  6.9
# 2      Aamir Khan                       1800                  8.1
# 3    Akshay Kumar                       2100                  6.8
# 4   Ranbir Kapoor                       1500                  7.3
# 5   Ranveer Singh                       1600                  7.4
# 6  Hrithik Roshan                       1700                  7.5
# 7      Ajay Devgn                       1900                  6.9
# 8    Varun Dhawan                       1200                  6.5
# 9    Tiger Shroff                       1100                  6.3
#
#   Years Considered       Notable Movie
# 0        2015-2025               Jawan
# 1        2015-2025             Tiger 3
# 2        2015-2025  Laal Singh Chaddha
# 3        2015-2025        Sooryavanshi
# 4        2015-2025              Animal
# ...

# %%
df.sort_values("Average IMDb Rating")
# Out:
#             Actor  Total Box Office (INR Cr)  Average IMDb Rating  \
# 9    Tiger Shroff                       1100                  6.3
# 8    Varun Dhawan                       1200                  6.5
# 3    Akshay Kumar                       2100                  6.8
# 1     Salman Khan                       2500                  6.9
# 7      Ajay Devgn                       1900                  6.9
# 4   Ranbir Kapoor                       1500                  7.3
# 5   Ranveer Singh                       1600                  7.4
# 6  Hrithik Roshan                       1700                  7.5
# 0  Shah Rukh Khan                       2200                  7.8
# 2      Aamir Khan                       1800                  8.1
#
#   Years Considered       Notable Movie
# 9        2015-2025            Baaghi 2
# 8        2015-2025             Bhediya
# 3        2015-2025        Sooryavanshi
# 1        2015-2025             Tiger 3
# 7        2015-2025             Tanhaji
# ...

# %%
df.sort_values("Average IMDb Rating", ascending = False)
# Out:
#             Actor  Total Box Office (INR Cr)  Average IMDb Rating  \
# 2      Aamir Khan                       1800                  8.1
# 0  Shah Rukh Khan                       2200                  7.8
# 6  Hrithik Roshan                       1700                  7.5
# 5   Ranveer Singh                       1600                  7.4
# 4   Ranbir Kapoor                       1500                  7.3
# 1     Salman Khan                       2500                  6.9
# 7      Ajay Devgn                       1900                  6.9
# 3    Akshay Kumar                       2100                  6.8
# 8    Varun Dhawan                       1200                  6.5
# 9    Tiger Shroff                       1100                  6.3
#
#   Years Considered       Notable Movie
# 2        2015-2025  Laal Singh Chaddha
# 0        2015-2025               Jawan
# 6        2015-2025                 War
# 5        2015-2025           Gully Boy
# 4        2015-2025              Animal
# ...

# %%
df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#             Actor  Total Box Office (INR Cr)  Average IMDb Rating  \
# 0  Shah Rukh Khan                       2200                  7.8
# 1     Salman Khan                       2500                  6.9
# 2      Aamir Khan                       1800                  8.1
# 3    Akshay Kumar                       2100                  6.8
# 4   Ranbir Kapoor                       1500                  7.3
# 5   Ranveer Singh                       1600                  7.4
# 6  Hrithik Roshan                       1700                  7.5
# 7      Ajay Devgn                       1900                  6.9
# 8    Varun Dhawan                       1200                  6.5
# 9    Tiger Shroff                       1100                  6.3
#
#   Years Considered       Notable Movie
# 0        2015-2025               Jawan
# 1        2015-2025             Tiger 3
# 2        2015-2025  Laal Singh Chaddha
# 3        2015-2025        Sooryavanshi
# 4        2015-2025              Animal
# ...

# %%
# Corrected code - removed the extra period
df["Rank"] = df["Average IMDb Rating"].rank(ascending = False)

# %%
df
# Out:
#             Actor  Total Box Office (INR Cr)  Average IMDb Rating  \
# 0  Shah Rukh Khan                       2200                  7.8
# 1     Salman Khan                       2500                  6.9
# 2      Aamir Khan                       1800                  8.1
# 3    Akshay Kumar                       2100                  6.8
# 4   Ranbir Kapoor                       1500                  7.3
# 5   Ranveer Singh                       1600                  7.4
# 6  Hrithik Roshan                       1700                  7.5
# 7      Ajay Devgn                       1900                  6.9
# 8    Varun Dhawan                       1200                  6.5
# 9    Tiger Shroff                       1100                  6.3
#
#   Years Considered       Notable Movie  Rank
# 0        2015-2025               Jawan   2.0
# 1        2015-2025             Tiger 3   6.5
# 2        2015-2025  Laal Singh Chaddha   1.0
# 3        2015-2025        Sooryavanshi   8.0
# ...

# %%
df = df[["Actor", "Notable Movie", "Rank", "Total Box Office (INR Cr)", "Average IMDb Rating", "Years Considered"]]

# %%
df
# Out:
#             Actor       Notable Movie  Rank  Total Box Office (INR Cr)  \
# 0  Shah Rukh Khan               Jawan   2.0                       2200
# 1     Salman Khan             Tiger 3   6.5                       2500
# 2      Aamir Khan  Laal Singh Chaddha   1.0                       1800
# 3    Akshay Kumar        Sooryavanshi   8.0                       2100
# 4   Ranbir Kapoor              Animal   5.0                       1500
# 5   Ranveer Singh           Gully Boy   4.0                       1600
# 6  Hrithik Roshan                 War   3.0                       1700
# 7      Ajay Devgn             Tanhaji   6.5                       1900
# 8    Varun Dhawan             Bhediya   9.0                       1200
# 9    Tiger Shroff            Baaghi 2  10.0                       1100
#
#    Average IMDb Rating Years Considered
# 0                  7.8        2015-2025
# 1                  6.9        2015-2025
# 2                  8.1        2015-2025
# ...
