# %%
import seaborn as sns
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
tips = sns.load_dataset('tips')

# %%
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')
sns.lineplot(x="total_bill", y="tip", data=tips)
plt.title('Line Plot Example')
plt.show()

# %%
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')
sns.barplot(x="total_bill", y="tip", data=tips)
plt.title('Bar Plot Example')
plt.show()

# %%
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')
sns.Scatterplot(x="total_bill", y="tip", data=tips)
plt.title('Scatter Plot Example')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 import matplotlib.pyplot as plt
#       2 tips = sns.load_dataset('tips')
# ----> 3 sns.Scatterplot(x="total_bill", y="tip", data=tips)
#       4 plt.title('Scatter Plot Example')
#       5 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'Scatterplot'

# %%
import matplotlib.pyplot as plt
import seaborn as sns  # Added the missing import for seaborn

tips = sns.load_dataset('tips')
sns.scatterplot(x="total_bill", y="tip", data=tips)  # Changed Scatterplot to scatterplot (lowercase)
plt.title('Scatter Plot Example')
plt.show()
